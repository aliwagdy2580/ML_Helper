# %% [markdown]
# <a href="https://colab.research.google.com/github/aliwagdy2580/ML_Helper/blob/main/download_dataset_from_kaggle_to_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing the [Kaggle API](https://github.com/Kaggle/kaggle-api) in Colab

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##upload json file

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-34518d51-889e-42e1-bd07-8860a648b644" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34518d51-889e-42e1-bd07-8860a648b644">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Downloading dataset from kaggle to colab

# %%
# !kaggle datasets download -d ruizgara/socofing
# Out:
# ...
#  99% 827M/838M [00:06<00:00, 140MB/s]
# 100% 838M/838M [00:06<00:00, 132MB/s]

# %%
# !unzip /content/socofing.zip

# %% [markdown]
# #downloading from kaggle to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d ruizgara/socofing -p /content/drive/MyDrive/new
# Out:
# ...
#  99% 829M/838M [00:07<00:00, 126MB/s]
# 100% 838M/838M [00:07<00:00, 119MB/s]

# %%
cd /content/drive/MyDrive/new
# Out:
# /content/drive/MyDrive/new

# %%
ls
# Out:
# socofing.zip

# %%
# !unzip /content/drive/MyDrive/new/socofing.zip
# Out:
# Archive:  /content/drive/MyDrive/new/socofing.zip
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_index_finger_CR.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_index_finger_Obl.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_index_finger_Zcut.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_little_finger_CR.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_little_finger_Obl.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_little_finger_Zcut.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_middle_finger_CR.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_middle_finger_Obl.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_middle_finger_Zcut.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_ring_finger_CR.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_ring_finger_Obl.BMP
#   inflating: SOCOFing/Altered/Altered-Easy/100__M_Left_ring_finger_Zcut.BMP
# ...
